# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      -------------- ----------------------- 112.6/293.3 kB 3.3 MB/s eta 0:00:01
#      ---------------------- --------------- 174.1/293.3 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\manoj\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("Data Science Salary 2021 to 2023.csv")

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023               EN              FT          Applied Scientist
# 1       2023               EN              FT          Applied Scientist
# 2       2023               EN              FT       Data Quality Analyst
# 3       2023               EN              FT    Compliance Data Analyst
# 4       2023               EN              FT          Applied Scientist
# 5       2023               EN              FT          Applied Scientist
# 6       2023               EN              FT  Machine Learning Engineer
# 7       2023               EN              FT  Machine Learning Engineer
# 8       2023               EN              FT         Research Scientist
# 9       2023               EN              FT              Data Engineer
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L
# 5  110680             USD         110680               US            L
# 6  163196             USD         163196               US            M
# 7  145885             USD         145885               US            M
# 8  220000             USD         220000               US            L
# 9   85000             USD          85000               US            M

# %%
styled_df = df.head(10).style.set_properties(**{'background-color': '#e793ff ' ,'color':'black','border-color': '#8b8c8c'})
styled_df.set_table_styles([
    {"selector": "th", "props": [("color", 'white'), ("background-color", "#333333")]}
])
# Out:
# <style type="text/css">
# #T_0efa0 th {
#   color: white;
#   background-color: #333333;
# }
# #T_0efa0_row0_col0, #T_0efa0_row0_col1, #T_0efa0_row0_col2, #T_0efa0_row0_col3, #T_0efa0_row0_col4, #T_0efa0_row0_col5, #T_0efa0_row0_col6, #T_0efa0_row0_col7, #T_0efa0_row0_col8, #T_0efa0_row1_col0, #T_0efa0_row1_col1, #T_0efa0_row1_col2, #T_0efa0_row1_col3, #T_0efa0_row1_col4, #T_0efa0_row1_col5, #T_0efa0_row1_col6, #T_0efa0_row1_col7, #T_0efa0_row1_col8, #T_0efa0_row2_col0, #T_0efa0_row2_col1, #T_0efa0_row2_col2, #T_0efa0_row2_col3, #T_0efa0_row2_col4, #T_0efa0_row2_col5, #T_0efa0_row2_col6, #T_0efa0_row2_col7, #T_0efa0_row2_col8, #T_0efa0_row3_col0, #T_0efa0_row3_col1, #T_0efa0_row3_col2, #T_0efa0_row3_col3, #T_0efa0_row3_col4, #T_0efa0_row3_col5, #T_0efa0_row3_col6, #T_0efa0_row3_col7, #T_0efa0_row3_col8, #T_0efa0_row4_col0, #T_0efa0_row4_col1, #T_0efa0_row4_col2, #T_0efa0_row4_col3, #T_0efa0_row4_col4, #T_0efa0_row4_col5, #T_0efa0_row4_col6, #T_0efa0_row4_col7, #T_0efa0_row4_col8, #T_0efa0_row5_col0, #T_0efa0_row5_col1, #T_0efa0_row5_col2, #T_0efa0_row5_col3, #T_0efa0_row5_col4, #T_0efa0_row5_col5, #T_0efa0_row5_col6, #T_0efa0_row5_col7, #T_0efa0_row5_col8, #T_0efa0_row6_col0, #T_0efa0_row6_col1, #T_0efa0_row6_col2, #T_0efa0_row6_col3, #T_0efa0_row6_col4, #T_0efa0_row6_col5, #T_0efa0_row6_col6, #T_0efa0_row6_col7, #T_0efa0_row6_col8, #T_0efa0_row7_col0, #T_0efa0_row7_col1, #T_0efa0_row7_col2, #T_0efa0_row7_col3, #T_0efa0_row7_col4, #T_0efa0_row7_col5, #T_0efa0_row7_col6, #T_0efa0_row7_col7, #T_0efa0_row7_col8, #T_0efa0_row8_col0, #T_0efa0_row8_col1, #T_0efa0_row8_col2, #T_0efa0_row8_col3, #T_0efa0_row8_col4, #T_0efa0_row8_col5, #T_0efa0_row8_col6, #T_0efa0_row8_col7, #T_0efa0_row8_col8, #T_0efa0_row9_col0, #T_0efa0_row9_col1, #T_0efa0_row9_col2, #T_0efa0_row9_col3, #T_0efa0_row9_col4, #T_0efa0_row9_col5, #T_0efa0_row9_col6, #T_0efa0_row9_col7, #T_0efa0_row9_col8 {
#   background-color: #e793ff;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_0efa0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0efa0_level0_col0" class="col_heading level0 col0" >work_year</th>
#       <th id="T_0efa0_level0_col1" class="col_heading level0 col1" >experience_level</th>
#       <th id="T_0efa0_level0_col2" class="col_heading level0 col2" >employment_type</th>
#       <th id="T_0efa0_level0_col3" class="col_heading level0 col3" >job_title</th>
#       <th id="T_0efa0_level0_col4" class="col_heading level0 col4" >salary</th>
#       <th id="T_0efa0_level0_col5" class="col_heading level0 col5" >salary_currency</th>
#       <th id="T_0efa0_level0_col6" class="col_heading level0 col6" >salary_in_usd</th>
#       <th id="T_0efa0_level0_col7" class="col_heading level0 col7" >company_location</th>
#       <th id="T_0efa0_level0_col8" class="col_heading level0 col8" >company_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0efa0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0efa0_row0_col0" class="data row0 col0" >2023</td>
#       <td id="T_0efa0_row0_col1" class="data row0 col1" >EN</td>
#       <td id="T_0efa0_row0_col2" class="data row0 col2" >FT</td>
#       <td id="T_0efa0_row0_col3" class="data row0 col3" >Applied Scientist</td>
#       <td id="T_0efa0_row0_col4" class="data row0 col4" >213660</td>
#       <td id="T_0efa0_row0_col5" class="data row0 col5" >USD</td>
#       <td id="T_0efa0_row0_col6" class="data row0 col6" >213660</td>
#       <td id="T_0efa0_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_0efa0_row0_col8" class="data row0 col8" >L</td>
#     </tr>
#     <tr>
#       <th id="T_0efa0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0efa0_row1_col0" class="data row1 col0" >2023</td>
#       <td id="T_0efa0_row1_col1" class="data row1 col1" >EN</td>
#       <td id="T_0efa0_row1_col2" class="data row1 col2" >FT</td>
#       <td id="T_0efa0_row1_col3" class="data row1 col3" >Applied Scientist</td>
#       <td id="T_0efa0_row1_col4" class="data row1 col4" >130760</td>
#       <td id="T_0efa0_row1_col5" class="data row1 col5" >USD</td>
#       <td id="T_0efa0_row1_col6" class="data row1 col6" >130760</td>
#       <td id="T_0efa0_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_0efa0_row1_col8" class="data row1 col8" >L</td>
#     </tr>
#     <tr>
#       <th id="T_0efa0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0efa0_row2_col0" class="data row2 col0" >2023</td>
#       <td id="T_0efa0_row2_col1" class="data row2 col1" >EN</td>
#       <td id="T_0efa0_row2_col2" class="data row2 col2" >FT</td>
#       <td id="T_0efa0_row2_col3" class="data row2 col3" >Data Quality Analyst</td>
#       <td id="T_0efa0_row2_col4" class="data row2 col4" >100000</td>
#       <td id="T_0efa0_row2_col5" class="data row2 col5" >USD</td>
#       <td id="T_0efa0_row2_col6" class="data row2 col6" >100000</td>
#       <td id="T_0efa0_row2_col7" class="data row2 col7" >NG</td>
#       <td id="T_0efa0_row2_col8" class="data row2 col8" >L</td>
#     </tr>
#     <tr>
#       <th id="T_0efa0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0efa0_row3_col0" class="data row3 col0" >2023</td>
#       <td id="T_0efa0_row3_col1" class="data row3 col1" >EN</td>
#       <td id="T_0efa0_row3_col2" class="data row3 col2" >FT</td>
#       <td id="T_0efa0_row3_col3" class="data row3 col3" >Compliance Data Analyst</td>
#       <td id="T_0efa0_row3_col4" class="data row3 col4" >30000</td>
#       <td id="T_0efa0_row3_col5" class="data row3 col5" >USD</td>
#       <td id="T_0efa0_row3_col6" class="data row3 col6" >30000</td>
#       <td id="T_0efa0_row3_col7" class="data row3 col7" >NG</td>
#       <td id="T_0efa0_row3_col8" class="data row3 col8" >L</td>
#     </tr>
#     <tr>
#       <th id="T_0efa0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0efa0_row4_col0" class="data row4 col0" >2023</td>
#       <td id="T_0efa0_row4_col1" class="data row4 col1" >EN</td>
#       <td id="T_0efa0_row4_col2" class="data row4 col2" >FT</td>
#       <td id="T_0efa0_row4_col3" class="data row4 col3" >Applied Scientist</td>
#       <td id="T_0efa0_row4_col4" class="data row4 col4" >204620</td>
#       <td id="T_0efa0_row4_col5" class="data row4 col5" >USD</td>
#       <td id="T_0efa0_row4_col6" class="data row4 col6" >204620</td>
#       <td id="T_0efa0_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_0efa0_row4_col8" class="data row4 col8" >L</td>
#     </tr>
#     <tr>
#       <th id="T_0efa0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0efa0_row5_col0" class="data row5 col0" >2023</td>
#       <td id="T_0efa0_row5_col1" class="data row5 col1" >EN</td>
#       <td id="T_0efa0_row5_col2" class="data row5 col2" >FT</td>
#       <td id="T_0efa0_row5_col3" class="data row5 col3" >Applied Scientist</td>
#       <td id="T_0efa0_row5_col4" class="data row5 col4" >110680</td>
#       <td id="T_0efa0_row5_col5" class="data row5 col5" >USD</td>
#       <td id="T_0efa0_row5_col6" class="data row5 col6" >110680</td>
#       <td id="T_0efa0_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_0efa0_row5_col8" class="data row5 col8" >L</td>
#     </tr>
#     <tr>
#       <th id="T_0efa0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0efa0_row6_col0" class="data row6 col0" >2023</td>
#       <td id="T_0efa0_row6_col1" class="data row6 col1" >EN</td>
#       <td id="T_0efa0_row6_col2" class="data row6 col2" >FT</td>
#       <td id="T_0efa0_row6_col3" class="data row6 col3" >Machine Learning Engineer</td>
#       <td id="T_0efa0_row6_col4" class="data row6 col4" >163196</td>
#       <td id="T_0efa0_row6_col5" class="data row6 col5" >USD</td>
#       <td id="T_0efa0_row6_col6" class="data row6 col6" >163196</td>
#       <td id="T_0efa0_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_0efa0_row6_col8" class="data row6 col8" >M</td>
#     </tr>
#     <tr>
#       <th id="T_0efa0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0efa0_row7_col0" class="data row7 col0" >2023</td>
#       <td id="T_0efa0_row7_col1" class="data ro

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3761 entries, 0 to 3760
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_year         3761 non-null   int64
#  1   experience_level  3761 non-null   object
#  2   employment_type   3761 non-null   object
#  3   job_title         3761 non-null   object
#  4   salary            3761 non-null   int64
#  5   salary_currency   3761 non-null   object
#  6   salary_in_usd     3761 non-null   int64
#  7   company_location  3761 non-null   object
#  8   company_size      3761 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 264.6+ KB

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd
# count  3761.000000  3.761000e+03    3761.000000
# mean   2022.374103  1.905999e+05  137555.178942
# std       0.691252  6.711457e+05   63022.267974
# min    2020.000000  6.000000e+03    5132.000000
# 25%    2022.000000  1.000000e+05   95000.000000
# 50%    2022.000000  1.375000e+05  135000.000000
# 75%    2023.000000  1.800000e+05  175000.000000
# max    2023.000000  3.040000e+07  450000.000000

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# work_year           0
# experience_level    0
# employment_type     0
# job_title           0
# salary              0
# salary_currency     0
# salary_in_usd       0
# company_location    0
# company_size        0
# dtype: int64

# %%
df['experience_level'] = df["experience_level"].replace('EN', 'ENTRY LEVEL')
df['experience_level'] = df["experience_level"].replace('EX', 'EXPERIENCED')
df['experience_level'] = df["experience_level"].replace('MI', 'MID-LEVEL')
df['experience_level'] = df["experience_level"].replace('SE', 'SENIOR')

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023      ENTRY LEVEL              FT          Applied Scientist
# 1       2023      ENTRY LEVEL              FT          Applied Scientist
# 2       2023      ENTRY LEVEL              FT       Data Quality Analyst
# 3       2023      ENTRY LEVEL              FT    Compliance Data Analyst
# 4       2023      ENTRY LEVEL              FT          Applied Scientist
# 5       2023      ENTRY LEVEL              FT          Applied Scientist
# 6       2023      ENTRY LEVEL              FT  Machine Learning Engineer
# 7       2023      ENTRY LEVEL              FT  Machine Learning Engineer
# 8       2023      ENTRY LEVEL              FT         Research Scientist
# 9       2023      ENTRY LEVEL              FT              Data Engineer
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L
# 5  110680             USD         110680               US            L
# 6  163196             USD         163196               US            M
# 7  145885             USD         145885               US            M
# 8  220000             USD         220000               US            L
# 9   85000             USD          85000               US            M

# %%
df['employment_type'] = df["employment_type"].replace('FT', 'Full Time')

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023      ENTRY LEVEL       Full Time          Applied Scientist
# 1       2023      ENTRY LEVEL       Full Time          Applied Scientist
# 2       2023      ENTRY LEVEL       Full Time       Data Quality Analyst
# 3       2023      ENTRY LEVEL       Full Time    Compliance Data Analyst
# 4       2023      ENTRY LEVEL       Full Time          Applied Scientist
# 5       2023      ENTRY LEVEL       Full Time          Applied Scientist
# 6       2023      ENTRY LEVEL       Full Time  Machine Learning Engineer
# 7       2023      ENTRY LEVEL       Full Time  Machine Learning Engineer
# 8       2023      ENTRY LEVEL       Full Time         Research Scientist
# 9       2023      ENTRY LEVEL       Full Time              Data Engineer
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L
# 5  110680             USD         110680               US            L
# 6  163196             USD         163196               US            M
# 7  145885             USD         145885               US            M
# 8  220000             USD         220000               US            L
# 9   85000             USD          85000               US            M
